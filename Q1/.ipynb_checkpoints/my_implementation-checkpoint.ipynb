# %% [markdown]
# # Q1 - SwishNet Implementation using Tensorflow

# %% [markdown]
# ## Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, Model, Input
from tensorflow.keras.layers import Conv1D, Multiply, Add, Concatenate, GlobalAveragePooling1D, Activation

import numpy as np
np.random.seed(2021)

# %%
tf.__version__
# Out:
# '1.15.0'

# %%
def __causal_gated_conv1D(x = None, filters = 16, length = 6, strides = 1):
    def causal_gated_conv1D(x, filters, length, strides):
        x_sigm = Conv1D(filters = filters //2,
                       kernel_size = length,
                       dilation_rate = strides,
                       strides = 1,
                       padding = "causal",
                       activation = "sigmoid")(x)
        
        x_tanh = Conv1D(filters = filters //2,
                       kernel_size = length,
                       dilation_rate = strides,
                       strides = 1,
                       padding = "causal",
                       activation = "tanh")(x)
        
        x_out = Multiply()([x_sigm, x_tanh])
        
        return x_out
    
    if x is None:
        return lambda _x: causal_gated_conv1D(x=_x, filters=filters, length=length, strides=strides)
    else:
        return causal_gated_conv1D(x=x, filters=filters, length=length, strides=strides)

# %%
def SwishNet(input_shape, classes, width_multiply=1):
    
    x_input = Input(shape = input_shape)
    
    # 1 block
    x_up = __causal_gated_conv1D(filters=16 * width_multiply, length=3)(x_input)
    x_down = __causal_gated_conv1D(filters=16 * width_multiply, length=6)(x_input)
    x = Concatenate()([x_up, x_down])
    
    # 2 block
    
    x_up = __causal_gated_conv1D(filters=8 * width_multiply, length=3)(x)
    x_down = __causal_gated_conv1D(filters=8 * width_multiply, length=6)(x)
    x = Concatenate()([x_up, x_down])
    
    # 3 block
    x_up = __causal_gated_conv1D(filters=8 * width_multiply, length=3)(x)
    x_down = __causal_gated_conv1D(filters=8 * width_multiply, length=6)(x)
    x_concat = Concatenate()([x_up, x_down])
    
    x = Add()([x, x_concat])
    
    # 4 block
    x_loop1 = __causal_gated_conv1D(filters=16 * width_multiply, length=3, strides=3)(x)
    x = Add()([x, x_loop1])

    # 5 block
    x_loop2 = __causal_gated_conv1D(filters=16 * width_multiply, length=3, strides=2)(x)
    x = Add()([x, x_loop2])

    # 6 block
    x_loop3 = __causal_gated_conv1D(filters=16 * width_multiply, length=3, strides=2)(x)
    x = Add()([x, x_loop3])

    # 7 block
    x_forward = __causal_gated_conv1D(filters=16 * width_multiply, length=3, strides=2)(x)

    # 8 block
    x_loop4 = __causal_gated_conv1D(filters=32 * width_multiply, length=3, strides=2)(x)

    # output
    x = Concatenate()([x_loop2, x_loop3, x_forward, x_loop4])
    x = Conv1D(filters=classes, kernel_size=1)(x)
    x = GlobalAveragePooling1D()(x)
    x = Activation("softmax")(x)

    model = Model(inputs=x_input, outputs=x)

    return model

# %%
net = SwishNet(input_shape=(16, 20), classes=2)
net.summary()
print(net.predict(np.random.randn(2, 16, 20)))
# Out:
# WARNING:tensorflow:From /Users/thevindegamboda/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 16, 20)       0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 16, 8)        488         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 16, 8)        488         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 16, 8)        968         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 16, 8)        968         input_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 16, 8)        0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 16, 8)        0           conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16)       0           multiply_1[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 16, 4)        196         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 16, 4)        196         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 16, 4)        388         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 16, 4)        388         concatenate_1[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 16, 4)        0           conv1d_5[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 16, 4)        0           conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 8)        0           multiply_3[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 16, 4)        100         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 16, 4)        100         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 16, 4)        196         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 16, 4)        196         concatenate_2[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 16, 4)        0           conv1d_9[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 16, 4)        0           conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 8)        0           multiply_5[0][0]
#                                                                  multiply_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16, 8)        0           concatenate_2[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 16, 8)        200         add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 16, 8)        200         add_1[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 16, 8)        0           conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 8)        0           add_1[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 16, 8)        200         add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 16, 8)        200         add_2[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 16, 8)        0           conv1d_15[0][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 8)        0           add_2[0][0]
#                                                                  multiply_8[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 16, 8)        200         add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 16, 8)        200         add_3[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 16, 8)        0           conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 8)        0           add_3[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 16, 8)        200         add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 16, 8)        200         add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 16, 16)       400         add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 16, 16)       400         add_4[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 16, 8)        0           conv1d_19[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 16, 16)       0           conv1d_21[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 40)       0           multiply_8[0][0]
#                                                                  multiply_9[0][0]
#                                                                  multiply_10[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 16, 2)        82          concatenate_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 2)            0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 2)            0           global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 7,154
# Trainable params: 7,154
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /Users/thevindegamboda/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# [[0.4833677  0.51663226]
#  [0.47845703 0.5215429 ]]
